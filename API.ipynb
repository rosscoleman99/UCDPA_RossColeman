# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns
import requests

# %%
cars = requests.get("https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/TEA28/JSON-stat/1.0/en/C03398V04090")

# %%
cars.head
# Out:
# <bound method NDFrame.head of                                                      0
# 0    b'{\r\n  "dataset": {\r\n    "dimension": {\r\...
# 1    b'dex": {\r\n            "TEA28C01": 0,\r\n   ...
# 2    b' Private Cars Licensed for the First Time",\...
# 3    b'    },\r\n          "unit": {\r\n           ...
# 4    b'{\r\n              "base": "Number"\r\n     ...
# ..                                                 ...
# 188  b'\n      93.0,\r\n      null,\r\n      104.0,...
# 189  b'98.0,\r\n      7.0,\r\n      null,\r\n      ...
# 190  b'40.0,\r\n      8.0,\r\n      15.0,\r\n      ...
# 191  b'   19.0,\r\n      52.0,\r\n      22.0,\r\n  ...
# 192  b'\r\n      182.0,\r\n      63.0,\r\n      nul...
#
# [193 rows x 1 columns]>

# %%
r = requests.get("https://ws.cso.ie/public/api.jsonrpc?data=%7B%22jsonrpc%22:%222.0%22,%22method%22:%22PxStat.Data.Cube_API.ReadDataset%22,%22params%22:%7B%22class%22:%22query%22,%22id%22:%5B%5D,%22dimension%22:%7B%7D,%22extension%22:%7B%22pivot%22:null,%22codes%22:false,%22language%22:%7B%22code%22:%22en%22%7D,%22format%22:%7B%22type%22:%22JSON-stat%22,%22version%22:%222.0%22%7D,%22matrix%22:%22TEA28%22%7D,%22version%22:%222.0%22%7D%7D")
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '{"jsonrpc":"2.0","result":{"class":"dataset","dimension":{"STATISTIC":{"category":{"index":["TEA28C01","TEA28C02"],"label":{"TEA28C01":"New Private Cars Licensed for the First Time","TEA28C02":"New Private Cars Licensed for the First Time Rank"},"unit":{"TEA28C01":{"decimals":0,"label":"Number","position":"end"},"TEA28C02":{"decimals":0,"label":"Number","position":"end"}}},"label":"Statistic"},"TLIST(A1)":{"category":{"index":["2014","2015","2016","2017","2018","2019","2020","2021"],"label":{"2014":"2014","2015":"2015","2016":"2016","2017":"2017","2018":"2018","2019":"2019","2020":"2020","2021":"2021"}},"label":"Year"},"C03398V04090":{"category":{"index":["ALF024","ALF025","ALF026","AUD015","AUD016","AUD018","AUD020","AUD025","AUD031","AUD043","AUD046","AUD089","AUD105","AUD107","AUD111","AUD124","AUD0128","AUD129","BMW012","BMW013","BMW021","BMW027","BMW028","BMW029","BMW041","BMW117","BMW128","BMW132","BMW142","BMW145","BMW148","BMW152","BMW154","BMW161","BMW168","BMW175","BMW184"
# ...

# %%
print(TEA28)
# Out:
#           jsonrpc                                             result    id
# class         2.0                                            dataset  None
# dimension     2.0  {'STATISTIC': {'category': {'index': ['TEA28C0...  None
# extension     2.0  {'matrix': 'TEA28', 'reasons': ['Planned Routi...  None
# href          2.0  https://ws.cso.ie/public/api.restful/PxStat.Da...  None
# id            2.0               [STATISTIC, TLIST(A1), C03398V04090]  None

# %%
cars = requests.get('https://ws.cso.ie/public/api.jsonrpc?data=%7B%22jsonrpc%22:%222.0%22,%22method%22:%22PxStat.Data.Cube_API.ReadDataset%22,%22params%22:%7B%22class%22:%22query%22,%22id%22:%5B%22TLIST(A1)%22%5D,%22dimension%22:%7B%22TLIST(A1)%22:%7B%22category%22:%7B%22index%22:%5B%222021%22%5D%7D%7D%7D,%22extension%22:%7B%22pivot%22:null,%22codes%22:false,%22language%22:%7B%22code%22:%22en%22%7D,%22format%22:%7B%22type%22:%22JSON-stat%22,%22version%22:%222.0%22%7D,%22matrix%22:%22TEA28%22%7D,%22version%22:%222.0%22%7D%7D')
cars = cars.json()
pd.DataFrame(cv19['Make and Model',]).head()

# %%
pd.DataFrame(space.json()).head()

# %%
TEA28 = pd.DataFrame(TEA28.json()).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [29], in <module>
# ----> 1 TEA28 = pd.DataFrame(TEA28.json()).head()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'json'
